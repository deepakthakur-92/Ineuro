# %%
import pandas as pd

# %%
df = pd.read_csv('D:/users1.csv')

# %%
df
# Out:
#          userEmail  password
# 0  Load03@Test.com  Test@123

# %%
for i in range(1, 51):
    df['password'] = 'Test@123'

# %%
df
# Out:
#          userEmail  password
# 0  Load03@Test.com  Test@123

# %%
import pandas as pd

# %%
list = [["Load@Test.com", "Test@123"]]

# %%
csvfile =  open("userss50.csv", "w+")

# %%
writer = csv.writer(csvfile)
writer.writerow(["userEmail", "password"])
for i in range(1, 51):
    writer.writerows(list)

# %%
list = []

for i in range(1, 51):
    list.append("load50_Test{}@Test.com" .format(i))
    
    
print(list)
# Out:
# ['load50_Test1@Test.com', 'load50_Test2@Test.com', 'load50_Test3@Test.com', 'load50_Test4@Test.com', 'load50_Test5@Test.com', 'load50_Test6@Test.com', 'load50_Test7@Test.com', 'load50_Test8@Test.com', 'load50_Test9@Test.com', 'load50_Test10@Test.com', 'load50_Test11@Test.com', 'load50_Test12@Test.com', 'load50_Test13@Test.com', 'load50_Test14@Test.com', 'load50_Test15@Test.com', 'load50_Test16@Test.com', 'load50_Test17@Test.com', 'load50_Test18@Test.com', 'load50_Test19@Test.com', 'load50_Test20@Test.com', 'load50_Test21@Test.com', 'load50_Test22@Test.com', 'load50_Test23@Test.com', 'load50_Test24@Test.com', 'load50_Test25@Test.com', 'load50_Test26@Test.com', 'load50_Test27@Test.com', 'load50_Test28@Test.com', 'load50_Test29@Test.com', 'load50_Test30@Test.com', 'load50_Test31@Test.com', 'load50_Test32@Test.com', 'load50_Test33@Test.com', 'load50_Test34@Test.com', 'load50_Test35@Test.com', 'load50_Test36@Test.com', 'load50_Test37@Test.com', 'load50_Test38@Test.com', 'load50_Test39@Tes
# ...

# %%
df1 = pd.DataFrame(list)

# %%
df1['password'] = 'Test@123'

# %%
df1.columns=['userEmail', 'password']

# %%
df1
# Out:
#                  userEmail  password
# 0    load50_Test1@Test.com  Test@123
# 1    load50_Test2@Test.com  Test@123
# 2    load50_Test3@Test.com  Test@123
# 3    load50_Test4@Test.com  Test@123
# 4    load50_Test5@Test.com  Test@123
# 5    load50_Test6@Test.com  Test@123
# 6    load50_Test7@Test.com  Test@123
# 7    load50_Test8@Test.com  Test@123
# 8    load50_Test9@Test.com  Test@123
# 9   load50_Test10@Test.com  Test@123
# 10  load50_Test11@Test.com  Test@123
# 11  load50_Test12@Test.com  Test@123
# 12  load50_Test13@Test.com  Test@123
# 13  load50_Test14@Test.com  Test@123
# 14  load50_Test15@Test.com  Test@123
# 15  load50_Test16@Test.com  Test@123
# 16  load50_Test17@Test.com  Test@123
# 17  load50_Test18@Test.com  Test@123
# 18  load50_Test19@Test.com  Test@123
# 19  load50_Test20@Test.com  Test@123
# 20  load50_Test21@Test.com  Test@123
# 21  load50_Test22@Test.com  Test@123
# 22  load50_Test23@Test.com  Test@123
# 23  load50_Test24@Test.com  Test@123
# ...

# %%
df1.to_csv("users50.csv")

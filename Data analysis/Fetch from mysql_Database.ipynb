# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(host="localhost",user="root", passwd="root",use_pure=True, database='world')

# %%
type(mydb)
# Out:
# mysql.connector.connection.MySQLConnection

# %%
mycursor=mydb.cursor()

# %%
type(mycursor)
# Out:
# mysql.connector.cursor.MySQLCursor

# %%
mycursor.execute('SELECT * FROM COUNTRY')
data = mycursor.fetchall()

# %%
len(data)
# Out:
# 239

# %%
for i in data:
    print(i[0])
# Out:
# ABW
# AFG
# AGO
# AIA
# ALB
# AND
# ANT
# ARE
# ARG
# ARM
# ASM
# ATA
# ATF
# ATG
# AUS
# AUT
# AZE
# BDI
# BEL
# BEN
# BFA
# BGD
# BGR
# BHR
# BHS
# BIH
# BLR
# BLZ
# BMU
# BOL
# BRA
# BRB
# BRN
# BTN
# BVT
# BWA
# CAF
# CAN
# CCK
# CHE
# CHL
# CHN
# CIV
# CMR
# COD
# COG
# COK
# COL
# COM
# CPV
# CRI
# CUB
# CXR
# CYM
# CYP
# CZE
# DEU
# DJI
# DMA
# DNK
# DOM
# DZA
# ECU
# EGY
# ERI
# ESH
# ESP
# EST
# ETH
# FIN
# FJI
# FLK
# FRA
# FRO
# FSM
# GAB
# GBR
# GEO
# GHA
# GIB
# GIN
# GLP
# GMB
# GNB
# GNQ
# GRC
# GRD
# GRL
# GTM
# GUF
# GUM
# GUY
# HKG
# HMD
# HND
# HRV
# HTI
# HUN
# IDN
# IND
# IOT
# IRL
# IRN
# IRQ
# ISL
# ISR
# ITA
# JAM
# JOR
# JPN
# KAZ
# KEN
# KGZ
# KHM
# KIR
# KNA
# KOR
# KWT
# LAO
# LBN
# LBR
# LBY
# LCA
# LIE
# LKA
# LSO
# LTU
# LUX
# LVA
# MAC
# MAR
# MCO
# MDA
# MDG
# MDV
# MEX
# MHL
# MKD
# MLI
# MLT
# MMR
# MNG
# MNP
# MOZ
# MRT
# MSR
# MTQ
# MUS
# MWI
# MYS
# MYT
# NAM
# NCL
# NER
# NFK
# NGA
# NIC
# NIU
# NLD
# NOR
# NPL
# NRU
# NZL
# OMN
# PAK
# PAN
# ...

# %%
query = 'SELECT  Continent, Region, District, GovernmentForm FROM city ci JOIN country co ON co.Code=ci.CountryCode'

mycursor.execute(query)
data = mycursor.fetchall()

# %%
for i in data:
    print(i)
# Out:
# ('North America', 'Caribbean', 'Â–', 'Nonmetropolitan Territory of The Netherlands')
# ('Asia', 'Southern and Central Asia', 'Kabol', 'Islamic Emirate')
# ('Asia', 'Southern and Central Asia', 'Qandahar', 'Islamic Emirate')
# ('Asia', 'Southern and Central Asia', 'Herat', 'Islamic Emirate')
# ('Asia', 'Southern and Central Asia', 'Balkh', 'Islamic Emirate')
# ('Africa', 'Central Africa', 'Luanda', 'Republic')
# ('Africa', 'Central Africa', 'Huambo', 'Republic')
# ('Africa', 'Central Africa', 'Benguela', 'Republic')
# ('Africa', 'Central Africa', 'Benguela', 'Republic')
# ('Africa', 'Central Africa', 'Namibe', 'Republic')
# ('North America', 'Caribbean', 'Â–', 'Dependent Territory of the UK')
# ('North America', 'Caribbean', 'Â–', 'Dependent Territory of the UK')
# ('Europe', 'Southern Europe', 'Tirana', 'Republic')
# ('Europe', 'Southern Europe', 'Andorra la Vella', 'Parliamentary Coprincipality')
# ...

# %% [markdown]
# # EDA on titanic dataset

# %%
import pandas as pd  
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(columns=['Cabin'],inplace=True)

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].fillna('S', inplace=True)

# %%
df['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df['Survived']=df['Survived'].astype('category')
df['Pclass']=df['Pclass'].astype('category')
df['Sex']=df['Sex'].astype('category')
df['Age']=df['Age'].astype('int')
df['Embarked']=df['Embarked'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    category
# dtypes: category(4), float64(1), int32(1), int64(3), object(2)
# memory usage: 49.2+ KB

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.544332    0.523008    0.381594   32.204208
# std     257.353842   13.013778    1.102743    0.806057   49.693429
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     223.500000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000   29.000000    0.000000    0.000000   14.454200
# 75%     668.500000   35.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.countplot(df['Survived'])
#death_percent=round((df['Survived'].value_counts().values[0]/891)*100)
# Out:
# C:\Users\deepak.thakur\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(df['Pclass'])
# Out:
# C:\Users\deepak.thakur\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(df['Sex'])
# Out:
# C:\Users\deepak.thakur\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.boxplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
df[(df['Age']>60) & (df['Age']<70)].shape[0]
# Out:
# 15

# %%
df[(df['Age']>=70) & (df['Age']<=75)].shape[0]
# Out:
# 6

# %%
df[(df['Age']>75) ].shape[0]
# Out:
# 1

# %%
sns.displot(df['Fare'])

# %% [markdown]
# # import pandas as pd

# %%
pd = pd.read_csv('D:/Player.csv')

# %%
pd.head(20)
# Out:
#     Player_Id      Player_Name        DOB Batting_Hand  \
# 0           1       SC Ganguly   8-Jul-72    Left_Hand
# 1           2      BB McCullum  27-Sep-81   Right_Hand
# 2           3       RT Ponting  19-Dec-74   Right_Hand
# 3           4        DJ Hussey  15-Jul-77   Right_Hand
# 4           5  Mohammad Hafeez  17-Oct-80   Right_Hand
# 5           6         R Dravid  11-Jan-73   Right_Hand
# 6           7         W Jaffer  16-Feb-78   Right_Hand
# 7           8          V Kohli   5-Nov-88   Right_Hand
# 8           9        JH Kallis  16-Oct-75   Right_Hand
# 9          10         CL White  18-Aug-83   Right_Hand
# 10         11       MV Boucher   3-Dec-76   Right_Hand
# 11         12          B Akhil   7-Oct-77   Right_Hand
# 12         13        AA Noffke  30-Apr-77   Right_Hand
# 13         14          P Kumar   2-Oct-86   Right_Hand
# 14         15           Z Khan   7-Oct-78   Right_Hand
# 15         16         SB Joshi   6-Jun-70    Left_Hand
# ...

# %%
pd.tail(10)
# Out:
#      Player_Id     Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 513        514       I Shivram        NaN          NaN                 NaN
# 514        515       SD Ranade        NaN          NaN                 NaN
# 515        516  TH Wijewardene        NaN          NaN                 NaN
# 516        517         AL Hill        NaN          NaN                 NaN
# 517        518       RJ Tucker        NaN          NaN                 NaN
# 518        519     Subroto Das        NaN          NaN                 NaN
# 519        520    K Srinivasan        NaN          NaN                 NaN
# 520        521       VK Sharma        NaN          NaN                 NaN
# 521        523     AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524     B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# 513        India          1         NaN
# 514        India          1         NaN
# ...

# %%
df = pd.read_csv('D:/Player.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df.head()

# %%
df.tail()
# Out:
#      Player_Id   Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 518        519   Subroto Das        NaN          NaN                 NaN
# 519        520  K Srinivasan        NaN          NaN                 NaN
# 520        521     VK Sharma        NaN          NaN                 NaN
# 521        523   AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524   B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#     Country  Is_Umpire  Unnamed: 7
# 518   India          1         NaN
# 519   India          1         NaN
# 520   India          1         NaN
# 521   India          0         NaN
# 522   India          0         NaN

# %%
df1.to_csv("test.csv")

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
pwd()
# Out:
# 'C:\\Users\\deepak.thakur\\ineuro\\Class Lectures'

# %%
pd.read_csv('test.csv')
# Out:
#    Unnamed: 0  Player_Id      Player_Name        DOB Batting_Hand  \
# 0           0          1       SC Ganguly   8-Jul-72    Left_Hand
# 1           1          2      BB McCullum  27-Sep-81   Right_Hand
# 2           2          3       RT Ponting  19-Dec-74   Right_Hand
# 3           3          4        DJ Hussey  15-Jul-77   Right_Hand
# 4           4          5  Mohammad Hafeez  17-Oct-80   Right_Hand
#
#         Bowling_Skill      Country  Is_Umpire  Unnamed: 7
# 0    Right-arm medium        India          0         NaN
# 1    Right-arm medium  New Zealand          0         NaN
# 2    Right-arm medium    Australia          0         NaN
# 3  Right-arm offbreak    Australia          0         NaN
# 4  Right-arm offbreak     Pakistan          0         NaN

# %%
df = pd.read_csv('D:/Player.csv', sep='#',header = None, names = ['a','b','c','d','e','f','g','h'], skiprows=[0,2,5])

# %%
df
# Out:
#        a             b          c           d                   e          f  \
# 0      1    SC Ganguly   8-Jul-72   Left_Hand    Right-arm medium      India
# 1      3    RT Ponting  19-Dec-74  Right_Hand    Right-arm medium  Australia
# 2      4     DJ Hussey  15-Jul-77  Right_Hand  Right-arm offbreak  Australia
# 3      6      R Dravid  11-Jan-73  Right_Hand  Right-arm offbreak      India
# 4      7      W Jaffer  16-Feb-78  Right_Hand  Right-arm offbreak      India
# ..   ...           ...        ...         ...                 ...        ...
# 516  519   Subroto Das        NaN         NaN                 NaN      India
# 517  520  K Srinivasan        NaN         NaN                 NaN      India
# 518  521     VK Sharma        NaN         NaN                 NaN      India
# 519  523   AV Wankhade  14-Mar-92  Right_Hand                 NaN      India
# 520  524   B Aparajith   8-Jul-94  Right_Hand  Right-arm offbreak      India
#
#      g   h
# 0    0 NaN
# 1    0 NaN
# ...

# %%
df = pd.read_csv('D:/Player.csv', sep='#', na_values=['SC Ganguly','BB McCullum'])

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1              NaN   8-Jul-72    Left_Hand    Right-arm medium
# 1            2              NaN  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df1 = pd.read_csv('D:/Player.csv', sep = "#", skiprows=[0,1,2])

# %%
df1
# Out:
#        3       RT Ponting  19-Dec-74  Right_Hand    Right-arm medium  \
# 0      4        DJ Hussey  15-Jul-77  Right_Hand  Right-arm offbreak
# 1      5  Mohammad Hafeez  17-Oct-80  Right_Hand  Right-arm offbreak
# 2      6         R Dravid  11-Jan-73  Right_Hand  Right-arm offbreak
# 3      7         W Jaffer  16-Feb-78  Right_Hand  Right-arm offbreak
# 4      8          V Kohli   5-Nov-88  Right_Hand    Right-arm medium
# ..   ...              ...        ...         ...                 ...
# 515  519      Subroto Das        NaN         NaN                 NaN
# 516  520     K Srinivasan        NaN         NaN                 NaN
# 517  521        VK Sharma        NaN         NaN                 NaN
# 518  523      AV Wankhade  14-Mar-92  Right_Hand                 NaN
# 519  524      B Aparajith   8-Jul-94  Right_Hand  Right-arm offbreak
#
#      Australia  0  Unnamed: 7
# 0    Australia  0         NaN
# 1     Pakistan  0         NaN
# 2        India  0         NaN
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#         Player_Id   Is_Umpire  Unnamed: 7
# count  523.000000  523.000000   12.000000
# mean   262.003824    0.099426    6.500000
# std    151.127981    0.299520    3.605551
# min      1.000000    0.000000    1.000000
# 25%    131.500000    0.000000    3.750000
# 50%    262.000000    0.000000    6.500000
# 75%    392.500000    0.000000    9.250000
# max    524.000000    1.000000   12.000000

# %%
df.dtypes
# Out:
# Player_Id          int64
# Player_Name       object
# DOB               object
# Batting_Hand      object
# Bowling_Skill     object
# Country           object
# Is_Umpire          int64
# Unnamed: 7       float64
# dtype: object

# %%
df.dtypes
# Out:
# Player_Id          int64
# Player_Name       object
# DOB               object
# Batting_Hand      object
# Bowling_Skill     object
# Country           object
# Is_Umpire          int64
# Unnamed: 7       float64
# dtype: object

# %%
df1 = pd.read_csv('D:/Player.csv', sep = "#")

# %%
df1
# Out:
#        3       RT Ponting  19-Dec-74  Right_Hand    Right-arm medium  \
# 0      4        DJ Hussey  15-Jul-77  Right_Hand  Right-arm offbreak
# 1      5  Mohammad Hafeez  17-Oct-80  Right_Hand  Right-arm offbreak
# 2      6         R Dravid  11-Jan-73  Right_Hand  Right-arm offbreak
# 3      7         W Jaffer  16-Feb-78  Right_Hand  Right-arm offbreak
# 4      8          V Kohli   5-Nov-88  Right_Hand    Right-arm medium
# ..   ...              ...        ...         ...                 ...
# 515  519      Subroto Das        NaN         NaN                 NaN
# 516  520     K Srinivasan        NaN         NaN                 NaN
# 517  521        VK Sharma        NaN         NaN                 NaN
# 518  523      AV Wankhade  14-Mar-92  Right_Hand                 NaN
# 519  524      B Aparajith   8-Jul-94  Right_Hand  Right-arm offbreak
#
#      Australia  0  Unnamed: 7
# 0    Australia  0         NaN
# 1     Pakistan  0         NaN
# 2        India  0         NaN
# ...

# %%
df1.to_csv("result4.csv", index = False, sep = "#", columns = ['Player_Id', 'DOB'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-1443a41e26fe> in <module>
# ----> 1 df1.to_csv("result4.csv", index = False, sep = "#", columns = ['Player_Id', 'DOB'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3145         from pandas.io.formats.csvs import CSVFormatter
#    3146
# -> 3147         formatter = CSVFormatter(
#    3148             df,
#    3149             path_or_buf,
#
# ...

# %%
df = pd.read_csv('D:/Player.csv', sep = "#")

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df.tail()
# Out:
#      Player_Id   Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 518        519   Subroto Das        NaN          NaN                 NaN
# 519        520  K Srinivasan        NaN          NaN                 NaN
# 520        521     VK Sharma        NaN          NaN                 NaN
# 521        523   AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524   B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#     Country  Is_Umpire  Unnamed: 7
# 518   India          1         NaN
# 519   India          1         NaN
# 520   India          1         NaN
# 521   India          0         NaN
# 522   India          0         NaN

# %%
df.columns
# Out:
# Index(['Player_Id', 'Player_Name', 'DOB', 'Batting_Hand', 'Bowling_Skill',
#        'Country', 'Is_Umpire', 'Unnamed: 7'],
#       dtype='object')

# %%
df['Player_Id']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 518    519
# 519    520
# 520    521
# 521    523
# 522    524
# Name: Player_Id, Length: 523, dtype: int64

# %%
type(df['Player_Id'])
# Out:
# pandas.core.series.Series

# %%
df[['Player_Id']]
# Out:
#      Player_Id
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ..         ...
# 518        519
# 519        520
# 520        521
# 521        523
# 522        524
#
# [523 rows x 1 columns]

# %%
type(df[['Player_Id']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Player_Id', 'Batting_Hand']]
# Out:
#      Player_Id Batting_Hand
# 0            1    Left_Hand
# 1            2   Right_Hand
# 2            3   Right_Hand
# 3            4   Right_Hand
# 4            5   Right_Hand
# ..         ...          ...
# 518        519          NaN
# 519        520          NaN
# 520        521          NaN
# 521        523   Right_Hand
# 522        524   Right_Hand
#
# [523 rows x 2 columns]

# %%
df[['Player_Id', 'Batting_Hand', 'Is_Umpire']]
# Out:
#      Player_Id Batting_Hand  Is_Umpire
# 0            1    Left_Hand          0
# 1            2   Right_Hand          0
# 2            3   Right_Hand          0
# 3            4   Right_Hand          0
# 4            5   Right_Hand          0
# ..         ...          ...        ...
# 518        519          NaN          1
# 519        520          NaN          1
# 520        521          NaN          1
# 521        523   Right_Hand          0
# 522        524   Right_Hand          0
#
# [523 rows x 3 columns]

# %%
df2 = pd.read_excel('D:\sample-excel-master\LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx', sheet_name='Create your instrument universe')

# %%
df4 = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")

# %%
df4
# Out:
# [       Season   Age                                   Team  \
#  0     2008-09  19.0  Did Not Play (other pro league—Spain)
#  1     2009-10  20.0                                    OKC
#  2     2010-11  21.0                                    OKC
#  3     2011-12  22.0                                    OKC
#  4     2012-13  23.0                                    OKC
#  5     2013-14  24.0                                    OKC
#  6     2014-15  25.0                                    OKC
#  7     2015-16  26.0                                    OKC
#  8     2016-17  27.0                                    TOT
#  9     2016-17  27.0                                    ORL
#  10    2016-17  27.0                                    TOR
#  11    2017-18  28.0                                    TOR
#  12    2018-19  29.0                                    TOR
#  13    2019-20  30.0                                    TOR
#  14    2020-21  31.0                                    LAC
# ...

# %%
type(df4)
# Out:
# list

# %%
len(df4)
# Out:
# 6

# %%
df4[0]
# Out:
#        Season   Age                                   Team  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
df4[3].to_csv("palyer.csv")

# %%
import pandas as pd
df4 = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")
for i in range(len(df4)):
    df4[i].to_csv(f"html_data{i}.csv")

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s = '''{
"name" : "deep",
"phone_no" : 45454545,
"company" : ["ineuron","Convegenius", "pacific", "emds", "concentrix"]
}
'''

# %%
import json
s1 = json.loads(s)

# %%
pd.DataFrame(s1, columns=['company'])
# Out:
#        company
# 0      ineuron
# 1  Convegenius
# 2      pacific
# 3         emds
# 4   concentrix

# %%
import requests

# %%
res = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
res
# Out:
# <Response [200]>

# %%
js = res.json()

# %%
js[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41840',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41840/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41840/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41840/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/41840',
#  'id': 912891173,
#  'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYzMDAzNDU2',
#  'number': 41840,
#  'title': 'doc: add highlight_quantile to style.rst',
#  'user': {'login': 'attack68',
#   'id': 24256554,
#   'node_id': 'MDQ6VXNlcjI0MjU2NTU0',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/24256554?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/attack68',
#   'html_url': 'https://github.com/attack68',
#   'followers_url': 'https://api.github.com/users/attack68/followers',
# ...

# %%
js[0]['user']
# Out:
# {'login': 'attack68',
#  'id': 24256554,
#  'node_id': 'MDQ6VXNlcjI0MjU2NTU0',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/24256554?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/attack68',
#  'html_url': 'https://github.com/attack68',
#  'followers_url': 'https://api.github.com/users/attack68/followers',
#  'following_url': 'https://api.github.com/users/attack68/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/attack68/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/attack68/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/attack68/subscriptions',
#  'organizations_url': 'https://api.github.com/users/attack68/orgs',
#  'repos_url': 'https://api.github.com/users/attack68/repos',
#  'events_url': 'https://api.github.com/users/attack68/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/attack68/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
js[0]['title']
# Out:
# 'doc: add highlight_quantile to style.rst'

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# doc: add highlight_quantile to style.rst
# DOC: Input/Output page contains only input functions
# ENH: Using transparentpath in read_csv
# ENH: DataFrame.to_expr() method
# _libs.hashtable.ismember incorrect with tuples containing nan
# BUG: Odd timezone offset change with old datetimes with tz_convert
# REF: de-duplicate symmetric_difference, _union
# REF: de-duplicate IntervalIndex setops
# BUG: IntervalIndex([np.nan, np.nan]).is_monotonic returns True
# TYP: datetimelike
# CI: Re-enable Circle CI
# ENH: retain attrs when concat dataframes
# BUG: DataFrame `isin` function randomly selects values (instead of using them all) when on Intel CPU and input is a torch Tensor
# ENH: Allow different senses of "distance" for method=nearest indexing
# REF: share wrapping in MultiIndex setops
# REF: de-duplicate Index._intersection + MultiIndex._intersection
# BUG: MultiIndex.unique incorrect when NA value is present
# DOC: Whatsnew1.3 grammar
# ...

# %%
pd.DataFrame(js, columns=['url', 'title'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df4 = pd.DataFrame(js)

# %%
df4.to_csv("")

# %%
l = []
for i in range(len(js)):
    l.append(js[i]['user'])
pd.DataFrame(l)
# Out:
#               login        id               node_id  \
# 0          attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 1          attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 2   michaelshekasta  41590425  MDQ6VXNlcjQxNTkwNDI1
# 3     kerrickstaley    184773  MDQ6VXNlcjE4NDc3Mw==
# 4      jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 5               rok     54589      MDQ6VXNlcjU0NTg5
# 6      jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 7      jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 8      jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 9      jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 10        lithomas1  47963215  MDQ6VXNlcjQ3OTYzMjE1
# 11     xiki-tempula   6242032  MDQ6VXNlcjYyNDIwMzI=
# 12       SamuelTrew  31927714  MDQ6VXNlcjMxOTI3NzE0
# 13        WardBrian  31640292  MDQ6VXNlcjMxNjQwMjky
# 14     jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 15     jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 16     jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# ...
